# %%
import numpy as np
from rdkit import Chem

# %%
#Chem.MolFromSmiles('O=C(CCSCc1ccco1)NNC(=O)N1Cc2ccccc2Oc2ccc(Cl)cc21')
Chem.MolFromSmiles('O=C(COC(=O)c1ccccc1Cc1ccccc1)Nc1cccc(S(=O)(=O)N=C2CCCN2)c1')
#Chem.MolFromSmiles('Cc1cc(C(=O)CN2C(=O)NC(C)(c3cccc(-n4cnnn4)c3)C2=O)c(C)n1C(C)c1ccccc1')
#Chem.MolFromSmiles('Cc1cnc(Nc2ccc(F)cc2Cl)nc1-c1c[nH]c(C(=O)N[C@H](CO)c2cccc(Cl)c2)c1')

# %%
mol1 = Chem.MolFromSmiles('O=C(CCSCc1ccco1)NNC(=O)N1Cc2ccccc2Oc2ccc(Cl)cc21')
#getting compound_id from SMILES, or vice-versa
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <module>
#       1 mol1 = Chem.MolFromSmiles('O=C(CCSCc1ccco1)NNC(=O)N1Cc2ccccc2Oc2ccc(Cl)cc21')
# ----> 3 mol1.compound_id()
#
# AttributeError: 'Mol' object has no attribute 'compound_id'

# %%
# !jt -l

# !jt -t oceans16
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl
